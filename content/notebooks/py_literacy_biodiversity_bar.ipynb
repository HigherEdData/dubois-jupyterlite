# %% [markdown]
# # Race, Literacy, and Neighborhood Biodiversity Bar Charts with Python:
#
# ## Black Literacy After Emancipation
#
# <div>
# <img src="https://github.com/HigherEdData/Du-Bois-STEM/blob/main/readings-images/original-plate-47.jpg?raw=true" width="700" />
# </div>

# %% [markdown]
# ### This interactive exercise is inspired by the annual #DuBoisChallenge
#
# The #DuBoisChallenge is a call to scientists, students, and community members to recreate, adapt, and share on social media the data visualzations created by W.E.B. Du Bois and his collaborators in 1900. Before doing the interactive exercise, please read this article about the Du Bois Challenge: **[here](https://nightingaledvs.com/the-dubois-challenge/)**.
#
# ### In this interactive excercise, you will:
#
# 1. Learn how to create a variation of a **bar graph.**
# 2. Learn how to write **Python** statistical software code to:
#     * create visualizations that consistently and accurately represent your data
#     * start from the minimum code necessary to make a simple graph, then add additional lines of code that each add a layer to your visualization
#     * create a transparent record of exactly how you visualized something
#     * make it easy for you or others to recreate or modify your visualization
# 3. Export an HTML file of your completed Notebook that your instructor may ask you to submit.
#
# ### You will acheive these learning objectives by creating two graphs with Python:
#
# 1. You will recreate Du Bois' visualization of Black illiteracy rates in the US compared to illiteracy rates in other countries. Du Bois created the visualization in 1900.
#
# 2. You will adapt Du Bois' visualization using data on **neighborhood biodiversity** and the historical redlining of neighborhoods according to the share of residents that were non-white.
#
# ### Historical Context for Du Bois' Original Graph:
#
# An important context of Du Bois's graph of Black illiteracy is that literacy was illegal for enslaved people in the U.S. until emancipation and the Confederacy's defeat during the Civil War. Illiteracy then declined rapidly as Black Americans sought to empower themselves through education. Du Bois plotted this decline in illiteracy among Black residents in the state of Georgia in the figure below.
#
# <details>
#
# <summary>About the data.</summary>
#
# Du Bois used decennial US census illiteracy rates for Georgia from 1860 to 1890 that are available **[here](https://babel.hathitrust.org/cgi/pt?id=njp.32101025729177&seq=49)**. They likely wrote "50%?" for the 1900 illiteracy rate because the Census did not publish 1900 illiteracy rates (available **[here](https://www2.census.gov/library/publications/decennial/1900/bulletins/demographic/8-negroes-in-us-part-1.pdf)**) until several months after the Paris Exposition.
# </details>
#
# <div>
# <img src="https://github.com/ajstarks/dubois-data-portraits/blob/master/plate14/original-plate-14.jpg?raw=true" width="700" />
# </div>

# %% [markdown]
# ### 1. How to use this interactive **Jupyter Notebook**
#
# If you have Jupyter Lab, you can also download this Notebook to use it on your own computer. You can download the Notebook or view a non-interactive version of this Notebook by clicking **[here](https://github.com/HigherEdData/Du-Bois-STEM/blob/main/r_literacy_dubois.ipynb)**.
#
# To use this Notebook interactively, Grey cells in the *Notebook* like the one below are **code cells** where you will write and edit **Python** Code. To try it out:
#
# 1. Click your cursor on the grey cell below. After you click on it, it will change to white to indicate you are editing it.
# 2. After you click on the cell below and it turns white. Type ```2+2``` to use Python as a calculator.
# 3. After typing ```print(2+2)```, click the <span class="play-button">&#9654;</span> *play button* at the top of this page.

# %% [markdown]
# ### 2. Keeping track of your work and using Python outside of this notebook.
#
# If you leave this Notebook idle or close and and re-open it, you're work will not be saved in the Notebook. But you can export an HTML file showing your work at any time. You can then open and browse the HTML file in any web browser.
#
# And after completing the Notebook exercises, you can export a final HTML file to submit for any course assignments using this Notebook.
#
# To export the Notebook, click the **File** dropdown above, select **Export File As** and then select **HTML** as shown here:
#
# <div>
# <img src="https://github.com/HigherEdData/Du-Bois-STEM/blob/main/readings-images/htmlexport.jpg?raw=true" width="500" />
# </div>

# %% [markdown]
# ### 3. Getting hints and answers.
#
# Sometimes, the code cells will already have code in them that you will be asked to edit or run by clicking the play button. In the process, you can click on <span class="play-button">&#9654;</span> dropdown buttons like the ones below to get hints and answers. For example:
# 1. Click on the cell below with ```print(3+3=)``` and click the play triangle above. You should get an error message highlighted in pink". To complete this activity, you'll want to get each code cell to run without a pink error message.
# 2. Based on the ```print(2+2)``` code you tried above, try to edit the ```print(3+3=)``` code to get it to report the sum of 3+3 without the error message. For a hint, click the first <span class="play-button">&#9654;</span> button below.

# %% [markdown]
# <details> <summary>Click this triangle for a hint.</summary>
#
# Try deleting the ```=``` sign in the cell and click play again. If that doesn't work, click the next triangle below for the answer.
#
# </details>

# %% [markdown]
# <details> <summary>Click this triangle for the answer.</summary>
#
# **Answer:** Delete all the text in the cell below and write or paste this answer in the cell: ```print(3+3)``` before clicking play again.
#
# </details>

# %%
print(3+3=)

# %% [markdown]
# ### 4. Reading and writing comments that explain your code
#
# In code cells, we can write **comment** text that explains our code. We put a ```# ``` before **comment** text to tell Python that the text is not code it should execute. Any text after a ```# ``` on a given line will be treated as a comment. In Jupyter, **comment** text after a ```# ``` will be displayed in a dark turquois color. To see how this works, try the following below:
#
# 1. Try to run the code below. You should get an error message because the comment text ```This is code that adds 2+2``` is not Python code and doesn't have a ```# ``` sign in front of it.
# 2. Add a ```# ``` sign before ```This is code that adds 2+2```. This should change the color of the text to turquois like the text after the ```print(2+2)``` where there is already a ```# ``` sign.
# 3. Click the <span class="play-button">&#9654;</span> at the top of the notebook and the code should run and output **4** below.

# %%
This is code that adds 2+2

print(2+2) # the result of 2 +2 should be 4

# %% [markdown]
# ### 5. Reading Du Bois' data into a Python Data Frame
#
# The first step for data visualization in **Python** is to **read** the data into a table, which is typically called a **dataframe** in python. This is like double clicking a file to open it in other computer programs. But with **Python**, we use code.
#
# There is no record of the exact data used by the Du Bois team for this bar graph. And the Du Bois graph curiously does not include tick marks with a labeled axis scale to show what exact values each bar represents. Why? Perhaps the Du Bois team wanted to emphasize that the bar graph was a rough comparison of illiteracy rates because of varied timing, methods, and national boundaries for measuring illiteracy rates at the time. The length of the "Negroes U.S.A." bar likely represents the national Black illiteracy rate of 57.1% reported by the 1890 US Census (see **[here](https://www2.census.gov/library/publications/decennial/1900/bulletins/demographic/8-negroes-in-us-part-1.pdf)**). So our data derives illiteracy rates for other countries based on the length of each country's bar relative to "Negroes U.S.A." bar, presuming the "Negroes U.S.A." bar represents 57.1%.
#
# To import this data, we will create two layers of code: an import layer and a loading layer. Below is a breakdown of what the different sections of code does within the two layers.
#
# 1. Import the **pandas** library of python code with functions for working with tables and dataframes. The code to import the library is: ```import pandas as pd```.
#
# 2. Import the **matplotlib.pyplot** library with functions for creating data visualizations from our dataframes. We'll use these functions to create our barchart next.
#
# 3. We read the data into our df **data frame** from a .csv file from its file path in Jupyter Lite with the code: ```df = pd.read_csv("d_literacy_country.csv."`)```. ```pd``` tells python that the ```read_csv``` function is from our **pandas** library.
# - If you try to do this outside of Jupyter Lite, replace the file path with the url for where we publish this data: https://raw.githubusercontent.com/HigherEdData/dubois-jupyterlite/main/content/data/d_literacy_country.csv
#
# 4. Write the name of our dataframe ```df```. This creates a scrollable table to browse our data.
#
# **Your Job**
#
# To do this yourself, replace the ```____``` portion of the code below to add the ```read_csv``` function and then press the <span class="play-button">&#9654;</span> above.

# %%
# Layer 1: Import Libary Features 
import pandas as pd # pandas helps with tabular data (spreadsheets, CSV files, etc.)
import matplotlib.pyplot as plt # matplotlib creates charts and graph

# Layer 2: Looad the data
df = pd.________("d_literacy_country.csv")

df
# Out:
#            country  illiteracy
# 0         Roumanie     73.3216
# 1           Servie     72.6727
# 2           Russie     72.6727
# 3  Negroes, U.S.A.     57.1000
# 4          Hongrie     55.8023
# 5           Italie     44.1227
# 6         Autriche     35.0386
# 7          Ireland     25.3057
# 8           France     12.9773
# 9            Suede      0.6489

# %% [markdown]
# ### 6. Creating a Bar Graph
#
# When writing code for data analysis, you want to start with the minimum code necessary. Then you add more lines of code to add layers to your analysis. You can see this method in action with data visualization, where additional lines of code add visual layers to your figure.
#
# This approach of starting simple and layering will produce code that is as simple and legible as possible for yourself and others, also producing clearer graphs.
#
# So our next step, is to write the shortest, simplest code possible to recreate Du Bois' **bar graph.**
#
# To write our initial simple code, we need to know which data Du Bois graphed from our data frame. After successfully displaying the data above, you should be able to see that it has data in two columns. Each column is a **variable**:
# * **country** is a country name for 10 countries with Black people in the U.S. treated as a country.
# * **illiteracy** containts percent of people in each country who are illiterate.
#
# **Your job for this step:** After reviewing the Du Bois' version of the graph above, fill in the ```_____``` characters in the code cell with the correct variable name for the y-axis variable and the x-axis variable to recreate Du Bois' graph.
#
# Filling in the blanks will complete the simplest code possible for telling Python to make the graph from these variables. You don't need to worry about what each element of of code does, but we explain what each layer of the code does following #'s for comments.

# %% [markdown]
# <details> <summary><strong>Hint:</strong></summary>
#
# Du Bois plotted ```illiteracy``` on the x-axis and ```country``` name on the y-axis.
#
# </details>

# %% [markdown]
# <details> <summary><strong>Answer:</strong></summary>
#
# The y-axis in layer three should be: ```df["country"],```
#
# The x-axis in layer three should be ```df["illiteracy"]```
#
# </details>

# %%
# Layer 1: Import Packages and Load Data
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("d_literacy_country.csv") # Load the data from CSV

# New Layer 2: Setup figure (overall chart area) with an ax (x y axes) subplot for the bar graph
fig, ax = plt.subplots()

# New Layer 3: Create a Horizontal Bar Chart

# Using the ax subplot tell it what data frame and variables to plot on the y-axis (bar name) and x-axis (bar length) 

ax.barh(
    df["_________"],  # y-axis df data frame source followed by var name in [] 
    df["_________"],  # x-axis df data frame source followed by var name in [] 
)
# Out:
# <BarContainer object of 10 artists>

# %% [markdown]
# ### 7. Adding a Bar Color Layer
#
# Now that we've produced our figure with the simplest code possible, we can start to add more visual layers by writing further lines of code.
#
# To see how this works, we will add layers that replicate Du Bois' use of a different bar color for Black Americans than for other countries. This will make it easier to see the comparison.
#
# To add a new 4th layer to your own graph, edit the code below to:
# 1. Fill in the blank in the ```bar_colors = ["____" if country == "Negroes, U.S.A."``` line of code with the **"red"** text that Du Bois uses for the Black U.S. resident category. That will complete a line of code that creates a variable **bar_colors** that designates which color each bar should be.
# 2. Fill in the blank of the ```color=__________,``` with the name of the new bar color variable you create.
#
# Note, some of the code for the new 4th layer as to before the code for our old layer 3.

# %% [markdown]
# <details> <summary><strong>Hints:</strong></summary>
#
# ```bar_colors``` is the name of the variable created that contains the bar color for each bar.
#
# </details>

# %% [markdown]
# <details> <summary><strong>Answer:</strong></summary>
#
# bar_colors =["red" if country == "Negroes, U.S.A."
#
# color= bar_colors,
#
# </details>

# %%
# Layer 1: Import Packages and Load Data
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("d_literacy_country.csv") # Load the data from CSV

# Layer 2: Setup figure (overall chart area)
fig, ax = plt.subplots()

#  New Layer 4: Apply Distinct Colors for Specific Variable

# Make a bar_colors variable that contains "red"
#  if country is "Negroes, U.S.A." and "dark green" for others

_________ =["red" if country == "Negroes, U.S.A."
    else "darkgreen" for country in df["country"]]

# Layer 3: Create a Horizontal Bar Chart

ax.barh(
    df["country"],  # y-axis df data frame source followed by var name in [] 
    df["illiteracy"],  # x-axis df data frame source followed by var name in [] 

# Addition to Layer 4:
    color= _________, # apply the red and green colors from the bar_colors variable
)
# Out:
# <BarContainer object of 10 artists>

# %% [markdown]
# #### Why Coding Produces Stronger Visualizations Than AI Assistants
#
# While trouble shooting code with an AI assistant may be practical in some instances, an AI assistant is not always ideal for producing data visualizations.
#
# In this next step we will refine the data visualization we produced above by adding and tuning up layers of code. If you were to try and refine the image solely through an AI assistant it would likely produce errors and not be able to produce the figure exactly as you need it to be. To test this you can try taking the image produced above and asking an AI assistant to make changes to it and see how it comes out. We bet that you are likely to spend more time trying to fix an image with an AI assistant than you would spend directly coding the data visualization your self.

# %% [markdown]
# ### 8. Adding Final Visual Layers and Titles With Your Own Name
#
# To recreate the literacy bar chart exactly as it was originally drawn by Du Bois' lab, we have to add multiple layers of code. We've done so in the code cell below with layers that add the following:
# * Space for titles by setting the figure's width to 11 by height to 14.
# * Change the background color
# * Remove the number line at the bottom to declutter the image
#
# Comments after #s in the code below explain which layers are added by new lines of code.
#
# **Your Job**
#
# To complete your recreation, fill in the blank in the code below to put subtitle text in the second **fig.text** function: ```"Recreated by ___________",``` to add your own name. This will show that the graph was recreated by you!

# %% [markdown]
# <details> <summary><strong>Details on how the new code adds additional layers and chart elements.</strong></summary>
#
# 1. Add a 5th layer that declutters and improves legibility throuh the following steps:
#
# - Flip y-axis order to go highest to lowest illiteracy with ```ax.invert_yaxis()``` command
# - Set background color of plot with ```ax.set_facecolor()``` command
# - Make country labels smaller and serif font with ```plt.yticks()``` command
# - Remove x-axis ticks with ```ax.set_xticks([])```and remove x-axis tickslabels with ```ax.set_xlabel("")``` command
# - Remove small tick marks from the y-axis with ```ax.tick_params()``` command
# - Remove the chart border lines (spines) with ```for spine in ax.spines.values(): spine.set_visible(False)``` command
#
# 2. Add a 6th layer that creates a title space for the figure. This includes:
#
# - Adjust position of the bar chart to make space for title with ```plt.subplots_adjust()``` command
# - Place the title in the margin above the subplot with ```fig.text()``` command
#
# 3. Add a 7th layer to insert subtitle with another```fig.text()``` command
#
# </details>

# %%
# Layer 1: Import Packages and Load Data
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("d_literacy_country.csv") # Load the data from CSV

# Layer 2: Setup figure (overall chart area)
fig, ax = plt.subplots(figsize=(11, 14), facecolor="antiquewhite")

#  Layer 4: Apply Distinct Colors for Specific Variable
bar_colors =["red" if country == "Negroes, U.S.A."
    else "darkgreen" for country in df["country"]]

# Layer 3: Create a Horizontal Bar Chart

ax.barh(
    df["country"],  # y-axis df data frame source followed by var name in [] 
    df["illiteracy"],  # x-axis df data frame source followed by var name in [] 
    
# Addition to Layer 4:
    color= bar_colors, # apply the red and green colors from the bar_colors variable
    height=0.5 # set bar height
)

# New Layer 5: Declutter and Improve Legibility of Figure

ax.invert_yaxis() # flip y-axis order to go highest to lowest illiteracy

ax.set_facecolor("antiquewhite") # set background color of plot

plt.yticks(fontsize=10, fontname="serif") # make country labels smaller and serif font

ax.set_xticks([]) # Remove x-axis ticks
ax.set_xlabel("") # Remove x-axis tickslabels

ax.tick_params(axis="y", left=False) # Remove small tick marks from the y-axis

for spine in ax.spines.values(): spine.set_visible(False) # Remove the chart border lines (spines)

# New Layer 6: Adjust Figure and Create Title

# Adjust position of the bar chart to make space for title
plt.subplots_adjust(left=0.25, right=0.85, top=.80, bottom=0.15)

# Place the title in the margin ABOVE the subplot
fig.text(
    0.5, 0.95, # Position in middle at top
    "\n" # add a line of above the title so it's not to close to top edge
    "Illiteracy of the American Negroes compared with that of other nations.",
    fontsize=14, fontname="serif", weight="bold", ha="center"
)

# New Layer 7: Add Subtitle

# Add a subtitle and center it across the figure
fig.text(
    0.5, 0.85,  # # Position in middle just below title
    "Proportion d' illettrés parmi les Nègres Américains comparée à celle des autres nations."
    "\n\n" # add space between subtitle lines
    "Done by Atlanta University."
    "\n\n" # add space between subtitle lines
    "Recreated by _____________",
    fontsize=12, fontname="serif", ha="center"
)

# %% [markdown]
# ### 9. Change the Data to Read in and Display Data on Biodiversity and Neighborhood Redlining Grades
#
# Now that you've written code to graph Du Bois' literacy data, you can use that same code to make bar graphs of other data in the same style.
#
# To see how this works, we will use data from an article in the Proceedings of the National Academy of Science (PNAS) **[here](https://www.pnas.org/doi/pdf/10.1073/pnas.2321441121)**  The article includes a bargraph showing lower biodiversity in neighborhoods that were redlined in the middle of the 20th century because they had large numbers of non-white residents. The home owners loan corporation (HOLC) tracked neighborhoods that would have been redlined by the Federal Housing Adminsation and local lenders, making it harder to get affordable homeloans in the neighborhood and "serving as a proxy for numerous prior and existing racialized policies at the federal, state, and local level that reinforced racial segregation, discrimination, and disinvestment" (Estian et al. 2024). The graph below uses data for the city of San Diego to show lower biodersity scores (0-100) in neighborhoods with lower A to D HOLC letter grades (indicating worse redlining treatment of neighborhoods).
#
# <div>
# <img src="https://github.com/HigherEdData/Du-Bois-STEM/blob/main/readings-images/biodiversity_redlining.png?raw=true" width="700" />
# </div>
#
# To recreate the biodiversity graph in the style of Du Bois' literacy graph, we need to first import the biodiversity data for San Diego neighborhoods from a different **d_biodiversity_redlining.csv** file.
#
# Do do this, fill in the blank in the file path line of code below to use the **d_biodiversity_redlining.csv** file. (If you're doing this outside of Jupyter Lite, use the url where we publish this data: https://raw.githubusercontent.com/HigherEdData/Du-Bois-STEM/refs/heads/main/data/d_biodiversity_redlining.
#
# Then the line of code **d_biodiversity_redlining** will display the diversity scores by neighborhood redlining grade from the graph above.

# %% [markdown]
# <details> <summary><strong>Hints:</strong></summary>
#
# Make sure that you include our **d_** prefix in the filename for the .csv at the end of the file name.
#
# </details>

# %% [markdown]
# <details> <summary><strong>Answer:</strong></summary>
#
# The first line of code should be:
#
# ```Python
#     url = "d_biodiversity_redlining.csv"
# ```
#
# </details>

# %%
# layer 1: Import Packages and Load Data
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("d__________________.csv")

df
# Out:
#   grade  biodiversity
# 0     A            48
# 1     B            24
# 2     C            12
# 3     D             4

# %% [markdown]
# ## 10. Edit the Du Bois Graph Code to Plot the Biodiversity and Neighborhood Redlining Grade Data
#
# After reading in the **d_biodiversity_redlining.csv** data, you can edit the graph code you used for the literacy code to graph the biodiversity and redlining data. Unlike the original biodiversity bar graph in the PNAS article, your code will graph the data as a horizontal bar graph.
#
# Fill in the blanks below to:
#
# 1. Change the name of the data frame you are graphing with ``plt.subplots`` to the **d_biodiversity_redlining** data frame.
# 2. Change the barh x-axis variable you are graphing from literacy to the **biodiversity** variable.
# 3. Change the barh y-axis variable you are graphing to the redlining **grade** variable.
# 4. Add your own name for the **Adapted by** line.

# %% [markdown]
# <details> <summary><strong>Hints:</strong></summary>
#
# The new dataframe name is ```d_biodiversity_redlining```.
#
# The x variable name is ```biodiversity```.
#
# </details>

# %% [markdown]
# <details> <summary><strong>Answer:</strong></summary>
#
# The code in the middle of the code cell should be:
#
# ```python
#     df["grade"],  # List of grades (y-axis)
#     df["biodiversity"],  # Biodiversity values (x-axis)
# ```
#
# </details>

# %%
# Layer 1: Import Packages and Load Data
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("d_biodiversity_redlining.csv")

# Layer 2: Setup figure (overall chart area)
fig, ax = plt.subplots(figsize=(11, 14), facecolor="antiquewhite")

#  Layer 4: Apply Distinct Colors for Specific Variable
bar_colors = ["red" if grade == "D" else "darkgreen" for grade in df["grade"]]

# Layer 3: Create a Horizontal Bar Chart

# Create a horizontal bar chart in the ax subplot by telling the ax.barh function
# what data frame and variables to plot on the y-axis (bar name) and x-axis (bar length) 

ax.barh(
    df["_____"],  # (y-axis)
    df["_____________"],  # (x-axis)

# Additiong to Layer 4:
    color=bar_colors,  # apply red and green colors to the bars with the color bar color variable
    # fill in the blank below to set the bar height
    height=0.5
)

# Layer 5: Declutter and Improve Legibility of Figure

ax.invert_yaxis() # flip y-axis order to go highest to lowest illiteracy

ax.set_facecolor("antiquewhite") # set background color of plot

plt.yticks(fontsize=10, fontname="serif")  # make country labels smaller and serif font

ax.set_xticks([]) # Remove x-axis ticks
ax.set_xlabel("") # Remove x-axis tickslabels

ax.tick_params(axis="y", left=False)  # Remove small tick marks from y-axis

# Remove the chart border lines (spines)
for spine in ax.spines.values(): spine.set_visible(False)

# Layer 6: Adjust Figure and Create Title

# Adjust position of the bar chart to make space for title
plt.subplots_adjust(left=0.25, right=0.85, top=0.8, bottom=0.15)

# Place the title in the margin ABOVE the subplot
fig.text(
    0.5, 0.95, # Position in middle at top
    "\n" # add a line of above the title so it's not to close to top edge
    "San Diego Neighborhood Biodiversity Score (0-100) by Neighborhood Redlining Grade.",
    fontsize=12, fontname="serif", weight="bold", ha="center"
)

# Layer 7: Add Subtitle

# Fully center subtitle across figure
fig.text(
    0.5, 0.85, # X and Y position (X=0.5 ensures full centering)
# fill in the blank below to translate the title in the language of
# your choice
    "Adapted by __________ from Du Bois' graph of literacy in 1900 and from"
        "\n\n"
# Fill in the blank below to show the graph is adapted by you!
    "'Historical redlining is associated with disparities in wildlife biodiversity in four California cities' (2024)",
    fontsize=10, fontname="serif", ha="center"
)
# Out:
# Text(0.5, 0.85, "Adapted by __________ from Du Bois' graph of literacy in 1900 and from\n\n'Historical redlining is associated with disparities in wildlife biodiversity in four California cities' (2024)")

# %% [markdown]
# ### 11. Improve Accessibility by Adding X Axis Grid Lines and Removing the Use of Red and Green
#
# Some of Du Bois' graphing choices might not make sense for graphs you want to make.
# For example, Du Bois doesn't provide labels or grid lines to make it easy to understand what the range of biodiversity scores are by neighborhood redlining grade. The code cell below adds two lines of code for adding the grid lines.
#
# In addition, red and green bars are difficult to differentiate for those with colorblindness. Try changing the color for the D grade bar to blue.
#
# If you want to customize the chart further to add your own style twist, try a google search or chatGPT query. For a chatGPT query, you could copy and paste the code from below and ask, **how could I change this python plt.subplot code to change the background color to beige?**
#
# To see how we made this subtle but importan change see *detail drop down section*.

# %% [markdown]
# <details> <summary><strong>Details on How We Added X-Axis Grid Lines.</strong></summary>
#
# 1. In the 5th layer, we commented out ```ax.set_xticks([])```
# 2. In the same layer we added ```ax.xaxis.grid(zorder=0)``` as a command to insert the tick marks
#
# </details>

# %%
# Layer 1: Import Packages and Load Data
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("d_biodiversity_redlining.csv")

# Layer 2: Setup figure (overall chart area)
fig, ax = plt.subplots(figsize=(11, 14), facecolor="antiquewhite")

# Layer 4: Apply Distinct Colors for Specific Variable
bar_colors = ["red" if grade == "D" else "darkgreen" for grade in df["grade"]]

# Layer 3: Create a Horizontal Bar Chart

# Create a horizontal bar chart in the ax subplot by telling the ax.barh function
# what data frame and variables to plot on the y-axis (bar name) and x-axis (bar length) 

ax.barh(
    df["grade"],  # (y-axis)
    df["biodiversity"],  # (x-axis)

# Addition to Layer 4:
    color=bar_colors,  # apply red and green colors to the bars with the color bar color variable
    # fill in the blank below to set the bar height
    height=0.5
)

# Layer 5: Declutter and Improve Legibility of Figure

ax.invert_yaxis() # flip y-axis order to go highest to lowest illiteracy

ax.set_facecolor("antiquewhite") # set background color of plot

plt.yticks(fontsize=10, fontname="serif")  # make country labels smaller and serif font

#ax.set_xticks([]) # Remove x-axis ticks
ax.set_xlabel("") # Remove x-axis tickslabels

ax.xaxis.grid(zorder=0)  # Add xaxis grid variable and set zorder to 0 so lines appear behind bars

ax.tick_params(axis="y", left=False)  # Remove small tick marks from y-axis

# Remove the chart border lines (spines)
for spine in ax.spines.values(): spine.set_visible(False)

# Layer 6: Adjust Figure and Create Title

# Adjust position of the bar chart to make space for title
plt.subplots_adjust(left=0.25, right=0.85, top=0.8, bottom=0.15)

# Place the title in the margin ABOVE the subplot
fig.text(
    0.5, 0.95, # Position in middle at top
    "\n" # add a line of above the title so it's not to close to top edge
    "San Diego Neighborhood Biodiversity Score (0-100) by Neighborhood Redlining Grade.",
    fontsize=12, fontname="serif", weight="bold", ha="center"
)

# Layer 7: Add Subtitle

# Fully center subtitle across figure
fig.text(
    0.5, 0.85, # X and Y position (X=0.5 ensures full centering)
# fill in the blank below to translate the title in the language of your choice
    "Adapted by __________ from Du Bois' graph of literacy in 1900 and from"
        "\n\n"
# Fill in the blank below to show the graph is adapted by you!
    "'Historical redlining is associated with disparities in  wildlife biodiversity in four California cities' (2024)",
    fontsize=10, fontname="serif", ha="center"
)
# Out:
# Text(0.5, 0.85, "Adapted by __________ from Du Bois' graph of literacy in 1900 and from\n\n'Historical redlining is associated with disparities in  wildlife biodiversity in four California cities' (2024)")

# %% [markdown]
# ### 12. Export a final HTML file of your Notebook
#
# Now that you're done, remember to export a final HTML file showing your work and displaying your name within the visualizations you created.
#
# As noted above, you can export the Notebook by clicking the **File** dropdown above, selecting **Export File As** and then selecting **HTML** as shown here:
# <div>
# <img src="https://github.com/HigherEdData/Du-Bois-STEM/blob/main/readings-images/htmlexport.jpg?raw=true" width="500" />
# </div>

# %% [markdown]
# # More Resources and References
#
# Github Repository for the #DuboisChallenge2024
# https://github.com/ajstarks/dubois-data-portraits/blob/master/challenge/2024/README.md
#
# Du Bois Challenge 2024 Recap
# https://speakerdeck.com/ajstarks/du-bois-challenge-2024-recap
#
# 2024 Du Bois Challenge using R Programming.
# https://medium.com/illumination/2024-du-bois-challenge-using-r-programming-02af8afa5626
#
# Developing Du Bois’s Data Portraits with Python and Matplotlib
# https://www.edriessen.com/2024/02/07/developing-du-boiss-data-portraits-with-python-and-matplotlib/
#
# Three Tricks I Learned In The Du Bois Data Visualization Challenge
# https://nightingaledvs.com/recreating-historical-dataviz-three-tricks-i-learned-in-the-du-bois-data-visualization-challenge/
#
# Molly Kuhs Du Bois Challenge repo
# https://github.com/makuhs/DuboisChallenge
#
# #DuBoisChallenge2024 using Python and Matplotlib
# https://github.com/edriessen/dubois24-python-matplotlib
#
# #DuboisChallenge2024 using R
# https://github.com/sndaba/2024DuBoisChallengeInRstats/tree/main
#
# #DuboisChallenge2024 using Tableau
# https://public.tableau.com/app/profile/camaal.moten7357/vizzes
